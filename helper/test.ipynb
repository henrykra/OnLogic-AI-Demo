# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
results2 = pd.read_csv('results2.csv')
results2
plt.plot(range(len(results2)), -1 * results2.y)

# %%
df = pd.read_csv('results.csv')
df
# Out:
#        t  cls         x          y
# 0    278  3.0  615.0000   96.34375
# 1    279  3.0  608.2500   96.56250
# 2    280  3.0  605.0000   96.75000
# 3    281  3.0  601.0000   97.03125
# 4    282  3.0  598.0000   97.31250
# ..   ...  ...       ...        ...
# 276  406  1.0  173.0000  430.43750
# 277  407  1.0  163.7500  451.12500
# 278  408  1.0  158.2500  474.00000
# 279  409  1.0  149.5625  480.00000
# 280  410  1.0  126.7500  479.12500
#
# [281 rows x 4 columns]

# %%
df_filter = df[(df['y'] >= 375) & (df['y'] <= 470)]

for e in range(4):
    


sns.scatterplot(data=df_filter, x='t', y='y', hue='cls')
# Out:
# <Axes: xlabel='t', ylabel='y'>

# %%
sns.lineplot(data=df, x='t', y='x', hue='cls')
# Out:
# <Axes: xlabel='t', ylabel='x'>

# %%
sns.scatterplot(data=df_filter, x='x', y='y', hue='cls')
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %%
import numpy as np
boundary = pd.read_csv('boundary.csv')

x = np.linspace(0, 320, 100)
y = 200 - .6 * x

sns.scatterplot(data = boundary, x='x', y='y')
plt.plot(x, y)
